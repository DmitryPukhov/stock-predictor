# %% [markdown]
# # Predict RTSI index with Random Forest models

# %% [markdown]
# [TOC]

# %% [markdown]
# ## Import libs

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, ParameterGrid
import seaborn as sns
import numpy as np
from pprint import pprint
#plt.style.use('seaborn')

# %% [markdown]
# ## Read data

# %%
# Read 1M OHLCV data from file instead of pdr.DataReader('RTSI','moex',start,end) because moex network source doesn't allow often downloads
df=pd.read_csv("/home/dima/projects/stock-predictor/data/RI.RTSI_180101_180313.csv", 
               parse_dates={'datetime':[2,3]}, 
               index_col='datetime')
#df=df.loc['2018-01-09']
df=df[['<OPEN>','<HIGH>','<LOW>','<CLOSE>','<VOL>']]
df.columns=['open','high','low','close','vol']
# Resample 1Min OHLC to 5Min OHLC
df=df.resample('5Min').agg({
        'open': 'first', 
        'high': 'max', 
        'low': 'min', 
        'close': 'last',
        'vol': 'sum'})
print(df.head())
df['close'].plot(title = 'Close price')
plt.ylabel('Close price')
plt.show()
# Out:
#                         open     high      low    close        vol
# datetime
# 2018-01-03 10:00:00  1156.44  1160.61  1156.28  1160.46  9175259.0
# 2018-01-03 10:05:00  1160.48  1162.36  1159.97  1160.41  3997514.0
# 2018-01-03 10:10:00  1163.29  1164.22  1163.15  1164.22  5464189.0
# 2018-01-03 10:15:00  1164.51  1165.31  1164.38  1164.72  3112672.0
# 2018-01-03 10:20:00  1164.72  1164.76  1163.23  1163.61  3283276.0

# %% [markdown]
# ## Prepare data

# %%
#lag = 5
# Fill in future values
target_names = ['open_fut', 'high_fut', 'low_fut', 'close_fut']
df['open_fut'] = df['open'].shift(-1)
df['high_fut'] = df['high'].shift(-1)
df['low_fut'] = df['low'].shift(-1)
df['close_fut'] = df['close'].shift(-1)

# Fill in prev values
prev_depth=5
feature_names=['open', 'high', 'low', 'close', 'vol']
for i in range(1,prev_depth):
    for name in ['open', 'high', 'low', 'close', 'vol']:
        prev_name = name+'_prev'+str(i)
        feature_names.append(prev_name)
        df[prev_name] = df[name].shift(i)
df = df.dropna()
features=df[feature_names]
targets = df[target_names]
sns.heatmap(df.loc[:,feature_names + target_names].corr())
plt.title('Features and targets correlations')
plt.show()
train_X, test_X, train_y, test_y = train_test_split(features, targets, shuffle=False)
# Out:
#                  open      high       low     close       vol  open_prev1  \
# open         1.000000  0.999613  0.999651  0.999217  0.076195    0.998654
# high         0.999613  1.000000  0.999518  0.999681  0.088222    0.998147
# low          0.999651  0.999518  1.000000  0.999648  0.068988    0.998210
# close        0.999217  0.999681  0.999648  1.000000  0.080838    0.997742
# vol          0.076195  0.088222  0.068988  0.080838  1.000000    0.075344
# open_prev1   0.998654  0.998147  0.998210  0.997742  0.075344    1.000000
# high_prev1   0.999108  0.998647  0.998587  0.998171  0.082076    0.999613
# low_prev1    0.999074  0.998478  0.998693  0.998141  0.071047    0.999651
# close_prev1  0.999414  0.998895  0.998975  0.998497  0.077945    0.999218
# vol_prev1    0.081367  0.087065  0.077365  0.083080  0.635107    0.076802
# open_prev2   0.997171  0.996627  0.996772  0.996300  0.072194    0.998656
# open_prev3    0.082664  0.994253  0.993704  0.993873   0.993400
# high_prev3    0.088344  0.994673  0.994183  0.994256   0.993834
# low_prev3     0.078667  0.994588  0.994001  0.994259   0.993734
# close_prev3   0.084368  0.994964  0.994438  0.994595   0.994122
# vol_prev3     0.635051  0.087358  0.090881  0.083985   0.087598
# open_prev4    0.078108  0.992804  0.992215  0.992383   0.991869
# high_prev4    0.090094  0.993261  0.992727  0.992813   0.992349
# low_prev4     0.070919  0.993148  0.992522  0.992795   0.992251
# close_prev4   0.082737  0.993547  0.992975  0.993165   0.992666
# vol_prev4     1.000000  0.088046  0.091555  0.084523   0.087830
# open_fut      0.088046  1.000000  0.999612  0.999650   0.999216
# high_fut      0.091555  0.999612  1.000000  0.999518   0.999680
# low_fut       0.084523  0.999650  0.999518  1.000000   0.999648
# close_fut     0.087830  0.999216  0.999680  0.999648   1.000000
#
# [29 rows x 29 columns]

# %% [markdown]
# ## Random Forest Regressor model

# %%
test_scores=[]
grid = ParameterGrid({'n_estimators': [200], 'max_depth':range(6), 'max_features':[1,2]})

# Hyperparameter tuning
rfr = RandomForestRegressor()
for g in grid:
    rfr.set_params(**g)
    rfr.fit(train_X, train_y)
    train_score=rfr.score(train_X, train_y)
    test_score=rfr.score(test_X,test_y)
    print('Hyperparameters: %s; train score: %s; test score: %s' % (g, train_score, test_score))
    test_scores.append(test_score)

# Get the best hyperparams combination
best_idx=np.argmax(test_scores)
g=grid[best_idx]
print('Best hyperparameters: %s' % g)

rfr.set_params(**g)
rfr.fit(train_X, train_y)
y = rfr.predict(test_X)
print('Train score: %s' % rfr.score(train_X, train_y))
print('Test score: %s' % rfr.score(test_X, test_y))
# Out:
# Hyperparameters: {'max_depth': 1, 'max_features': 1, 'n_estimators': 200}; train score: 0.534554240111; test score: -1.31207653119
# Hyperparameters: {'max_depth': 1, 'max_features': 2, 'n_estimators': 200}; train score: 0.72695994066; test score: -0.386250627052
# Hyperparameters: {'max_depth': 2, 'max_features': 1, 'n_estimators': 200}; train score: 0.775535156832; test score: -0.484205114355
# Hyperparameters: {'max_depth': 2, 'max_features': 2, 'n_estimators': 200}; train score: 0.927705621146; test score: 0.30906798228
# Hyperparameters: {'max_depth': 3, 'max_features': 1, 'n_estimators': 200}; train score: 0.897712225207; test score: 0.0670991611807
# Hyperparameters: {'max_depth': 3, 'max_features': 2, 'n_estimators': 200}; train score: 0.984940700469; test score: 0.734180273656
# Hyperparameters: {'max_depth': 4, 'max_features': 1, 'n_estimators': 200}; train score: 0.940758276822; test score: 0.307704681991
# Hyperparameters: {'max_depth': 4, 'max_features': 2, 'n_estimators': 200}; train score: 0.995845603522; test score: 0.845877802803
# Hyperparameters: {'max_depth': 5, 'max_features': 1, 'n_estimators': 200}; train score: 0.967431977671; test score: 0.489260701251
# Hyperparameters: {'max_depth': 5, 'max_features': 2, 'n_estimators': 200}; train score: 0.997472174504; test score: 0.897071824737
# Hyperparameters: {'max_depth': 6, 'max_features': 1, 'n_estimators': 200}; train score: 0.982550009437; test score: 0.624208527567
# Hyperparameters: {'max_depth': 6, 'max_features': 2, 'n_estimators': 200}; train score: 0.998060197449; test score: 0.907498780849
# Hyperparameters: {'max_depth': 7, 'max_features': 1, 'n_estimators': 200}; train score: 0.991380922075; test score: 0.711522525444
# Hyperparameters: {'max_depth': 7, 'max_features': 2, 'n_estimators': 200}; train score: 0.998585506105; test score: 0.911784914721
# Hyperparameters: {'max_depth': 8, 'max_features': 1, 'n_estimators': 200}; train score: 0.994450927176; test score: 0.749434809882
# Hyperparameters: {'max_depth': 8, 'max_features': 2, 'n_estimators': 200}; train score: 0.998885163183; test score: 0.903533017896
# Hyperparameters: {'max_depth': 9, 'max_features': 1, 'n_estimators': 200}; train score: 0.997224862493; test score: 0.815552840342
# Hyperparameters: {'max_depth': 9, 'max_features': 2, 'n_estimators': 200}; train score: 0.99905943028; test score: 0.902729064314
# Best hyperparameters: {'n_estimators': 200, 'max_features': 2, 'max_depth': 7}
# Train score: 0.998574658705
# Test score: 0.911879179145

# %% [markdown]
# ### Random Forest Regressor prediction EDA

# %%
data = pd.DataFrame()
data['price'] = test_y
data['predicted'] = y
data.plot(linestyle='none', marker='.', title = 'Predicted and real prices')
#data.plot(title = 'Predicted and real prices')
plt.show()

sns.scatterplot(x = test_y, y = y)
plt.title('Predicted and real prices scatterplot')
plt.xlabel('real price')
plt.ylabel('predicted price')
plt.show()

(data['predicted'] - data['price']).plot(title = 'Predicted diff', linestyle='none', marker='.',)
plt.ylabel('predicted price - real price')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/anaconda/lib/python3.6/site-packages/pandas/core/common.py in _asarray_tuplesafe(values, dtype)
#     376
# --> 377
#     378 def _get_callable_name(obj):
#
# ValueError: could not broadcast input array from shape (1143,4) into shape (1143)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _ensure_valid_index(self, value)
#    2375         Reflect the DataFrame over its main diagonal by writing rows as columns
# -> 2376         and vice-versa. The property :attr:`.T` is an accessor to the method
#    2377         :meth:`transpose`.
#
# ~/anaconda/lib/python3.6/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     247                     data = data.to_dense()
# --> 248
#     249             if index is None:
#
# ~/anaconda/lib/python3.6/site-packages/pandas/core/series.py in _sanitize_array(data, index, dtype, copy, raise_cast_failure)
#    3028     max    1.127688
# -> 3029     dtype: float64
#    3030
#
# ~/anaconda/lib/python3.6/site-packages/pandas/core/common.py in _asarray_tuplesafe(values, dtype)
#     379     # typical case has name
# --> 380     if hasattr(obj, '__name__'):
#     381         return getattr(obj, '__name__')
#
# ValueError: cannot copy sequence with size 4 to array axis with dimension 1143
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-7b885094704c> in <module>()
#       1 data = pd.DataFrame()
# ----> 2 data['price'] = test_y
#       3 data['predicted'] = y
#       4 data.plot(linestyle='none', marker='.', title = 'Predicted and real prices')
#       5 #data.plot(title = 'Predicted and real prices')
#
# ~/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2329
#    2330         >>> df.memory_usage()
# -> 2331         Index            80
#    2332         int64         40000
#    2333         float64       40000
#
# ~/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2394         --------
#    2395         numpy.transpose : Permute the dimensions of a given array.
# -> 2396
#    2397         Notes
#    2398         -----
#
# ~/anaconda/lib/python3.6/site-packages/pandas/core/frame.py in _ensure_valid_index(self, value)
#    2376         and vice-versa. The property :attr:`.T` is an accessor to the method
#    2377         :meth:`transpose`.
# -> 2378
#    2379         Parameters
#    2380         ----------
#
# ValueError: Cannot set a frame with no defined index and a value that cannot be converted to a Series

# %%
# Analyze feature importances
imp = rfr.feature_importances_
sorted_idx=np.argsort(imp)[::-1]
sorted_labels = np.array(train_X.columns[sorted_idx])

plt.bar(sorted_labels, imp[sorted_idx])
plt.title('Feature importances')
plt.ylabel('Importance')

plt.show()

# %%
ToDo: Add indicators, past bars to input...
