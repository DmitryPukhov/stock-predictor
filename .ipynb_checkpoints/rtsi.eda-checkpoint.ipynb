# %% [markdown]
# # RTSI Index EDA

# %% [markdown]
# ## TOC

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import pandas_datareader as pdr
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from statsmodels.graphics import tsaplots
import statsmodels.api as sm
from pylab import rcParams
import time
plt.style.use('fivethirtyeight')

# %% [markdown]
# ## Read RTSI Index data

# %%
df=pd.read_csv("/home/dima/projects/stock-predictor/data/RI.RTSI_180101_180313.csv", 
               parse_dates={'datetime':[2,3]}, 
               index_col='datetime')
df=df[['<OPEN>','<HIGH>','<LOW>','<CLOSE>','<VOL>']]
df.columns=['open','high','low','close','vol']
df = pd.DataFrame(df['close'])
df.tail()
#RTSI = pd.read_csv('/home/dima/projects/stock-predictor/data/MOEX.RTSI_20050101_201806.csv', parse_dates=['TRADEDATE'], index_col=0) 
#RTSI = RTSI[['OPEN','HIGH','LOW','CLOSE','VALUE']] 
#RTSI=RTSI.rename(columns={'OPEN': 'Open','HIGH':'High','LOW':'Low','CLOSE':'Close','VALUE':'Vol'})
#RTSI.tail()
# Out:
#                        close
# datetime
# 2018-03-13 18:38:00  1283.12
# 2018-03-13 18:39:00  1283.14
# 2018-03-13 18:40:00  1283.21
# 2018-03-13 18:41:00  1283.21
# 2018-03-13 18:51:00  1285.80

# %% [markdown]
# ## Price plot
# todo: normalize the data

# %%
ax = df.plot(marker='.', linestyle='none', markersize=1)
ax.set_title("RTSI")
plt.show()

# %%
fig=plt.figure()
# Price boxplot
ax1=fig.add_subplot(121)
df.boxplot(ax=ax1)
ax1.set_title("Price boxplot")
ax1.set_ylabel("Price")

# Price density plot
ax2 = fig.add_subplot(122)
df.plot(kind='density', ax=ax2)
ax2.set_title('Price density')
plt.tight_layout()

plt.show()

# %% [markdown]
# ## Average % change, aggregated by week and day
# Todo: normalize the data

# %%
# Plot % change by week day
fig=plt.figure()
ax1 = fig.add_subplot(121)
(df.pct_change()*100).groupby(df.index.dayofweek+1).mean().plot.bar(ax=ax1)
ax1.xaxis.set_major_locator(MaxNLocator(integer=True))
ax1.set_xlabel("Day of week")
ax1.set_ylabel("% change")
ax1.set_title("Avg % change by day of week")

# Plot # change by hour of the day
ax2=fig.add_subplot(122)
(df.pct_change()*100).groupby(df.index.hour).mean().plot.bar(ax=ax2)
ax2.xaxis.set_major_locator(MaxNLocator(integer=True))
ax2.set_xlabel("Day hour")
ax1.set_ylabel("% change")
ax2.set_title("Avg  % change by hour of the day")
plt.subplots_adjust(right=2)
plt.show()

# %% [markdown]
# ## Autocorrelation and partial autocorrelatoin
# ToDo: normalize the data

# %%
# Plot % change by week day
fig=plt.figure()
ax1 = fig.add_subplot(121)
tsaplots.plot_acf(df, lags=10, ax=ax1)

# Plot # change by hour of the day
ax2=fig.add_subplot(122)
tsaplots.plot_pacf(df, lags=10, ax=ax2)

plt.subplots_adjust(right=2)
plt.show()

# %% [markdown]
# ## Seasonality, trend and noise

# %%
#rcParams['figure.figsize'] = 11,9
decomposition = sm.tsa.seasonal_decompose(df, freq=60)
decomposition.plot()
plt.show()
