# %% [markdown]
# # RTSI Index EDA

# %% [markdown]
# ## TOC

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import pandas_datareader as pdr
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
from statsmodels.graphics import tsaplots
import statsmodels.api as sm
from pylab import rcParams
import time
plt.style.use('fivethirtyeight')
# Out:
# /home/dima/anaconda/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %% [markdown]
# ## Read RTSI Index data

# %%
ohlcv=pd.read_csv("/home/dima/projects/stock-predictor/data/RI.RTSI_180101_180313.csv", 
               parse_dates={'datetime':[2,3]}, 
               index_col='datetime')
ohlcv=ohlcv[['<OPEN>','<HIGH>','<LOW>','<CLOSE>','<VOL>']]
ohlcv.columns=['open','high','low','close','vol']
#ohlcv = ohlcv
df=pd.DataFrame(ohlcv['close'].diff().dropna())
df.tail()
#RTSI = pd.read_csv('/home/dima/projects/stock-predictor/data/MOEX.RTSI_20050101_201806.csv', parse_dates=['TRADEDATE'], index_col=0) 
#RTSI = RTSI[['OPEN','HIGH','LOW','CLOSE','VALUE']] 
#RTSI=RTSI.rename(columns={'OPEN': 'Open','HIGH':'High','LOW':'Low','CLOSE':'Close','VALUE':'Vol'})
#RTSI.tail()
# Out:
#                      close
# datetime
# 2018-03-13 18:38:00  -0.65
# 2018-03-13 18:39:00   0.02
# 2018-03-13 18:40:00   0.07
# 2018-03-13 18:41:00   0.00
# 2018-03-13 18:51:00   2.59

# %%
df.describe()
# Out:
#               close
# count  24077.000000
# mean       0.005281
# std        0.690869
# min      -34.750000
# 25%       -0.260000
# 50%        0.010000
# 75%        0.260000
# max       21.770000

# %% [markdown]
# ## Price plot
# todo: normalize the data

# %%
ax = df.plot(marker='.', linestyle='none', markersize=1, fontsize=6)
ax.set_title("RTSI")
plt.show()

# %%
fig=plt.figure()
# Price boxplot
ax1=fig.add_subplot(121)
df.boxplot(ax=ax1)
ax1.set_title("Price boxplot")
ax1.set_ylabel("Price")

# Price density plot
ax2 = fig.add_subplot(122)
df.plot(kind='density', ax=ax2)
ax2.set_title('Price density')
plt.subplots_adjust(right=2)

plt.show()

# %% [markdown]
# ## Average % change, aggregated by week and day
# Todo: normalize the data

# %%
# Plot % change by week day
fig=plt.figure()
ax1 = fig.add_subplot(121)
df.groupby(df.index.dayofweek+1).mean().plot.bar(ax=ax1)
ax1.xaxis.set_major_locator(MaxNLocator(integer=True))
ax1.set_xlabel("Day of week")
ax1.set_ylabel("Diff")
ax1.set_title("Avg diff by day of week")

# Plot # change by hour of the day
ax2=fig.add_subplot(122)
df.groupby(df.index.hour).mean().plot.bar(ax=ax2)
ax2.xaxis.set_major_locator(MaxNLocator(integer=True))
ax2.set_xlabel("Day hour")
ax1.set_ylabel("Diff")
ax2.set_title("Avg diff by hour of the day")
plt.subplots_adjust(right=2)
plt.show()

# %% [markdown]
# ## Autocorrelation and partial autocorrelatoin
# ToDo: normalize the data

# %%
# Plot % change by week day
fig=plt.figure()
ax1 = fig.add_subplot(121)
tsaplots.plot_acf(df, lags=60, ax=ax1)

# Plot # change by hour of the day
ax2=fig.add_subplot(122)
tsaplots.plot_pacf(df, lags=60, ax=ax2)

plt.subplots_adjust(right=2)
plt.show()

# %% [markdown]
# ## Seasonality, trend and noise
# Todo: detect seasonality properly

# %%
rcParams['figure.figsize'] = 11,9
# 1200 minutes in a day
decomposition = sm.tsa.seasonal_decompose(df, freq=1200)
decomposition.plot()
plt.show()
